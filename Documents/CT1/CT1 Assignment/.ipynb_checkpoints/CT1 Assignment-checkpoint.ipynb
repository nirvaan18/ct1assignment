# %%
import pandas as pd  
df = pd.read_csv(r'C:\Users\lavan\OneDrive\Desktop\ISB\TERM 2\CT1\Group Assignment\Wholesale customers data.csv')
  # Reading dataset in CSV format into a pandas DataFrame.

# %%
df.to_parquet('dataset.parquet')  # Save the DataFrame in Parquet format for efficient storage and reading.

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %% [markdown]
# ### PROFILING THE DATASET
# ##### Profiling gives insights into data distributions, missing values, and correlations.
# ##### The report helps in understanding data quality and identifying preprocessing steps.

# %%
# !pip install ydata-profiling

from ydata_profiling import ProfileReport  # A library to generate detailed data profiling reports.
profile = ProfileReport(df, title="Dataset Profile")  # Creates a profile of the dataset to summarize its structure and quality.
profile.to_file("profile_report.html")  # Saves the profiling report as an HTML file for easy viewing.
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/390.6 kB ? eta -:--:--
#    --------------------------------------- 390.6/390.6 kB 12.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/296.5 kB ? eta -:--:--
#    --------------------------------------- 296.5/296.5 kB 17.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/666.4 kB ? eta -:--:--
#    --------------------------------------  665.6/666.4 kB 13.9 MB/s eta 0:00:01
#    --------------------------------------- 666.4/666.4 kB 14.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/104.8 kB ? eta -:--:--
#    ---------------------------------------- 104.8/104.8 kB 5.9 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27092 sha256=ed56659ec4a040fec95b25b1e5b2353ef7efe4f0c4a1f662adf51dd44fd79823
# ...

# %% [markdown]
# ## Reading the Dataset

# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

# %%
wcust_df = pd.read_csv( r'C:\Users\lavan\OneDrive\Desktop\ISB\TERM 2\CT1\Group Assignment\Wholesale customers data.csv' )

# %% [markdown]
# ## Creating Data Profile

# %%
profile = ProfileReport(wcust_df, title="Pandas wcust Profiling Report")

# %%
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-12-04 11:51:48.989553&quot;&gt;&lt;title&gt;Pandas wcust Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %% [markdown]
# #### 3: Train-Test-Production Split
# * train_test_split ensures reproducible random splits using random_state.
# * The 60-20-20 split mimics a real-world scenario where production data is distinct from test data.

# %%
from sklearn.model_selection import train_test_split  #  function to split datasets into train and test sets.
train, temp = train_test_split(df, test_size=0.4, random_state=42)  # Splits 60% for training and 40% for testing + production.
test, prod = train_test_split(temp, test_size=0.5, random_state=42)  # Splits the remaining 40% into test and production (20% each)# Saves the train, test and prod set to a Parquet file.
.
train.to_parquet('train.parquetle.
test.to_parquet('test.parquetile.
prod.to_parquet('prod.parquefile.

# %% [markdown]
# #### 4: Data Version Control
# * Version control tracks dataset changes, ensuring collaboration and reproducibility.
# * Meaningful commit messages document what changes were made and why.

# %%
git init  # Initializes a new Git repository in the current directory.
# Out:
#   Cell In[10], line 1
#     git init  # Initializes a new Git repository in the current directory.
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 5: ML Pipeline with Scikit-Learn
# * Pipelines standardize preprocessing steps for consistency and reuse.
# * ColumnTransformer handles feature-specific transformations.

# %%
git add .  # Stages all files for commit.
git commit -m "Initial commit"  # Commits the staged files with a meaningful message.
git remote add origin <https://github.com/nirvaan18/ct1assignment.git>  # Links the local repo to a GitHub remote repository.
git push -u origin main  # Pushes the local repository's main branch to GitHub.
